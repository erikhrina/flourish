# %% [markdown]
# # Data Cleaning
# Jupyter Notebook used to clean and prepare the image dataset for ML model development.
#
# ### **Setup:**
#
# To run the notebook, you'll first need to download the Kaggle dataset available at:
#
# [🌱 House Plant Species 🌱](https://www.kaggle.com/datasets/kacpergregorowicz/house-plant-species)
#
# Save this dataset in the `/Data/` folder before running the code.
#
# ---

# %% [markdown]
# ### Constants

# %%
base_dir = '../Data/house_plant_species'
""" Folder path to the base directory containing species subfolders with images. """
# Out:
# ' Folder path to the base directory containing species subfolders with images. '

# %% [markdown]
# ### Helper Functions

# %%
import hashlib

def calculate_md5(file_path):
    """
    Calculate the MD5 hash of a file.

    Parameters:
        file_path (str): The path to the file whose MD5 hash needs to be calculated. 

    Returns:
        str: A string representing the MD5 hash of the file in hexadecimal format.

    Example Usage:
        file_path = 'example.txt'
        md5_hash = calculate_md5(file_path)
        print(f"MD5 Hash: {md5_hash}")
    """
    hasher = hashlib.md5()
    with open(file_path, 'rb') as f:
        while chunk := f.read(4096):
            hasher.update(chunk)
    return hasher.hexdigest()

# %%
import os

def find_duplicates(folder_path):
    """ 
    Find duplicate files in a folder.

    Parameters:
        folder_path (str): The path to the folder in which to find the duplicate files.
    
    Returns:
        list: A list of tuples, where each tuple contains the paths of duplicate files.
    
    Example Usage:
        folder_path = '/path/to/folder'
        duplicates = find_duplicates_in_folder(folder_path)
        for dup in duplicates:
            print(f"Duplicate: {dup[0]} and {dup[1]}")
    """
    hashes = {}
    duplicates = []
    
    for image_name in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_name)
        if os.path.isfile(image_path):
            img_hash = calculate_md5(image_path)
            if img_hash in hashes:
                duplicates.append((image_path, hashes[img_hash]))
            else:
                hashes[img_hash] = image_path

    return duplicates

# %%
import cv2

def convert_to_jpg(folder_path):
    """
    Convert images in a folder to JPEG format.

    Parameters:
        folder_path (str): The path to the folder containing images to convert.

    How It Works:
        - Reads each file in the folder.
        - Drops the alpha channel if the image has 4 channels.
        - If the file is not already in JPEG format, converts and saves it as a JPEG.
        - Deletes the original file after successful conversion.

    Notes:
        - Only valid image files will be processed.
        - If an image cannot be read, a warning is displayed, and the file is skipped.

    Example Usage:
        folder_path = '/path/to/folder'
        convert_to_jpg(folder_path)
    """
    for image_name in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_name)

        if os.path.isfile(image_path):
            image = cv2.imread(image_path)
            if image is None:
                print(f'Warning: Failed to read image: {image_path}')
                continue

            # If the image has 4 channels, drop the alpha channel
            if image.shape[2] == 4:
                image = image[:, :, :3]

            # Convert and save as JPEG if necessary
            new_image_name = f"{os.path.splitext(image_name)[0]}.jpg"
            new_image_path = os.path.join(folder_path, new_image_name)

            if not image_name.lower().endswith('.jpg'):
                success = cv2.imwrite(new_image_path, image)

                if success:
                    print(f'Converted to JPEG: {new_image_path}')
                    os.remove(image_path)  # Remove the original file
                else:
                    print(f'Failed to save JPEG for {image_path}, skipping.')

# %% [markdown]
# ### Clean the dataset

# %%
# Obtain a list of subfolders (classes)
subfolders = []
dir_content = os.listdir(base_dir)

for file_name in dir_content:
    file_path = os.path.join(base_dir, file_name)
    if os.path.isdir(file_path):
        subfolders.append(file_name)

len(subfolders), subfolders
# Out:
# (47,
#  ['African Violet (Saintpaulia ionantha)',
#   'Aloe Vera',
#   'Anthurium (Anthurium andraeanum)',
#   'Areca Palm (Dypsis lutescens)',
#   'Asparagus Fern (Asparagus setaceus)',
#   'Begonia (Begonia spp.)',
#   'Bird of Paradise (Strelitzia reginae)',
#   'Birds Nest Fern (Asplenium nidus)',
#   'Boston Fern (Nephrolepis exaltata)',
#   'Calathea',
#   'Cast Iron Plant (Aspidistra elatior)',
#   'Chinese evergreen (Aglaonema)',
#   'Chinese Money Plant (Pilea peperomioides)',
#   'Christmas Cactus (Schlumbergera bridgesii)',
#   'Chrysanthemum',
#   'Ctenanthe',
#   'Daffodils (Narcissus spp.)',
#   'Dracaena',
#   'Dumb Cane (Dieffenbachia spp.)',
#   'Elephant Ear (Alocasia spp.)',
#   'English Ivy (Hedera helix)',
#   'Hyacinth (Hyacinthus orientalis)',
#   'Iron Cross begonia (Begonia masoniana)',
#   'Jade plant (Crassula ovata)',
#   'Kalanchoe',
#   'Lilium (Hemerocallis)',
#   'Lily of the valley (Convallaria majalis)',
#   'Money Tree (Pachira aquatica)',
#   'Monstera Deliciosa (Monstera deliciosa)',
#   'Orchid',
#   'Parlor Palm (Chamaedorea elegans)',
#   'Peace lily',
#   'Poinsettia (Euphorbia pulcherrima)',
#   'Polka Dot Plant (Hypoestes phyllostachya)',
#   'Ponytail Palm (Beaucarnea recurvata)',
#   'Pothos (Ivy arum)',
#   'Prayer Plant (Maranta leuconeura)',
#   'Rattlesnake Plant (Calathea lancifolia)',
#   'Rubber Plant (Ficus elastica)',
#   'Sago Palm (Cycas revoluta)',
#   'Schefflera',
#   'Snake plant (Sanseviera)',
#   'Tradescantia',
#   'Tulip',
#   'Venus Flytrap',
#   'Yucca',
#   'ZZ Plant (Zamioculcas zamiifolia)'])

# %%
# Clean images by folder
for folder in subfolders:
    folder_path = os.path.join(base_dir, folder)
    
    print(f'Processing folder: {folder_path}')
    
    # Find duplicates
    duplicates = find_duplicates(folder_path)
    if duplicates:
        for duplicate in duplicates:
            os.remove(duplicate)
            print(f'Duplicate found and removed: {duplicate}')
    
    # Convert to jpg
    convert_to_jpg(folder_path)
# Out:
# Processing folder: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\123.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\149.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\166.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\181.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\186.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\193.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\232.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\24.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\246.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\268.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\278.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\3.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\31.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\321.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\4.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\71.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\75.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\78.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\90.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\94.jpg
# Converted to JPEG: ../Data/house_plant_species\African Violet (Saintpaulia ionantha)\95.jpg
# Processing folder: ../Data/house_plant_species\Aloe Vera
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\105.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\11.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\116.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\127.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\132.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\138.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\139.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\14.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\141.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\145.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\149.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\17.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\175.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\185.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\187.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\21.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\219.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\232.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\234.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\236.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\241.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\244.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\29.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\31.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\42.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\7.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\75.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\81.jpg
# Converted to JPEG: ../Data/house_plant_species\Aloe Vera\82.jpg
# Processing folder: ../Data/house_plant_species\Anthurium (Anthurium andraeanum)
# Converted to JPEG: ../Data/house_plant_species\Anthurium (Anthurium andraeanum)\1.jpg
# Converted to JPEG: ../Data/house_plant_species\Anthurium (Anthurium andraeanum)\130.jpg
# Converted to JPEG: ../Data/house_plant_species\Anthurium (Anthurium andraeanum)\150.jpg
# Converted to JPEG: ../Data/house_plant_species\Anthurium (Anthurium andraeanum)\153.jpg
# Converted to JPEG: ../Data/house_plant_species\Anthurium (Anthurium andraeanum)
jpg
# Converted to JPEG: ../Data/house_plant_species\Elephant Ear (Alocasia spp.)\185.jpg
# Converted to JPEG: ../Data/house_plant_species\Elephant Ear (Alocasia spp.)\191.jpg
# Converted to JPEG: ../Data/house_plant_species\Elephant Ear (Alocasia spp.)\199.jpg
# Converted to JPEG: ../Data/house_plant_species\Elephant Ear (Alocasia spp.)\20.jpg
# Converted to JPEG: ../Data/house_plant_species\Elephant Ear (Alocasia spp.)\203.jpg
# Converted to JPEG: ../Data/house_plant_species\Elephant Ear (Alocasia spp.)\210.jpg
# Converted to JPEG: ../Data/house_plant_species\Elephant Ear (Alocasia spp.)\22.jpg
# Converted to JPEG: ../Data/house_plant_species\Elephant Ear (Alocasia spp.)\222.jpg
# Converted to JPEG: ../Data/house_plant_species\Elephant Ear (Alocasia spp.)\227.jpg
# Converted to JPEG: ../Data/house_plant_species\Elephant Ear (Alocasia spp.)\24.jpg
# ...
# Converted to JPEG: ../Data/house_plant_species\Schefflera\190.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\191.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\193.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\195.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\203.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\206.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\219.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\220.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\227.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\238.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\244.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\25.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\255.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\259.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\267.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\268.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\273.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\280.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\282.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\287.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\288.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\292.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\303.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\312.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\320.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\326.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\36.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\40.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\43.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\46.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\51.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\53.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\58.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\61.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\64.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\66.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\68.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\75.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\8.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\89.jpg
# Converted to JPEG: ../Data/house_plant_species\Schefflera\92.jpg
# Processing folder: ../Data/house_plant_species\Snake plant (Sanseviera)
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\101.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\107.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\108.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\109.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\111.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\124.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\125.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\131.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\138.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\140.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\148.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\150.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\155.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\158.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\163.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\165.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\168.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\17.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\171.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\18.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\180.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\182.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\185.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\209.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\22.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\223.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\228.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\230.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\240.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\243.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\253.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\255.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\257.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\26.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\261.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\265.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\266.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\270.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\283.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\286.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\301.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\307.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\309.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\319.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\347.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\350.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\353.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\365.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\366.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\372.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\385.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\395.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\49.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\52.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\54.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\57.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\60.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\63.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\64.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\74.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\78.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\83.jpg
# Converted to JPEG: ../Data/house_plant_species\Snake plant (Sanseviera)\98.jpg
# Processing folder: ../Data/house_plant_species\Tradescantia
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\104.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\110.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\131.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\132.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\133.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\141.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\144.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\145.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\150.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\161.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\176.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\19.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\198.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\226.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\23.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\237.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\242.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\244.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\247.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\250.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\257.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\266.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\27.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\277.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\28.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\280.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\29.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\300.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\316.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\320.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\322.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\337.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\6.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\78.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\80.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\88.jpg
# Converted to JPEG: ../Data/house_plant_species\Tradescantia\89.jpg
# Processing folder: ../Data/house_plant_species\Tulip
# Converted to JPEG: ../Data/house_plant_species\Tulip\115.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\126.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\14.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\154.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\16.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\164.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\200.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\218.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\25.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\255.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\267.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\276.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\281.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\284.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\30.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\302.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\32.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\85.jpg
# Converted to JPEG: ../Data/house_plant_species\Tulip\87.jpg
# Processing folder: ../Data/house_plant_species\Venus Flytrap
# Converted to JPEG: ../Data/house_plant_species\Venus Flytrap\104.jpg
# Converted to JPEG: ../Data/house_plant_species\Venus Flytrap\139.jpg
# Converted to JPEG: ../Data/house_plant_species\Venus Flytrap\16.jpg
# Converted to JPEG: ../Data/house_plant_species\Venus Flytrap\173.jpg
# Converted to JPEG: ../Data/house_plant_species\Venus Flytrap\175.jpg
# Converted to JPEG: ../Data/house_plant_species\Venus Flytrap\179.jpg
# Converted to JPEG: ../Data/house_plant_species\Venus Flytrap\40.jpg
# Converted to JPEG: ../Data/house_plant_species\Venus Flytrap\67.jpg
# Converted to JPEG: ../Data/house_plant_species\Venus Flytrap\68.jpg
# Converted to JPEG: ../Data/house_plant_species\Venus Flytrap\87.jpg
# Processing folder: ../Data/house_plant_species\Yucca
# Converted to JPEG: ../Data/house_plant_species\Yucca\15.jpg
# Converted to JPEG: ../Data/house_plant_species\Yucca\23.jpg
# Converted to JPEG: ../Data/house_plant_species\Yucca\25.jpg
# Converted to JPEG: ../Data/house_plant_species\Yucca\28.jpg
# Converted to JPEG: ../Data/house_plant_species\Yucca\36.jpg
# Converted to JPEG: ../Data/house_plant_species\Yucca\9.jpg
# Processing folder: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\108.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\115.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\120.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\121.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\123.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\136.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\152.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\162.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\165.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\169.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\173.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\177.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\182.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\184.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\197.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\215.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\22.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\220.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\230.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\268.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\278.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\28.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\297.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\299.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\357.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\359.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\368.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\37.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\385.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\390.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\403.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\404.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\49.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\66.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\82.jpg
# Converted to JPEG: ../Data/house_plant_species\ZZ Plant (Zamioculcas zamiifolia)\89.jpg
